# %%
from bs4 import BeautifulSoupfrom, NavigableString, Tag
import urllib.request


blank = pd.DataFrame()
i = 0
# for i in range(0):
#     print(i)
r = urllib.request.urlopen('https://www.nacc.go.th/nacc_accuse_preview.php?offset=' + str(i*20) + 'accuse_id=&bn_number=&accused_position=&accused_ministry=&accused_indictment=&hstart=&hend=').read()
soup = BeautifulSoup(r)
table = soup.find("table", {"class": "tableTest"})
count = 0
data = {}
for td in table.findAll('td'):
    if count == 5:
        count = 0 
    if str(count) in data.keys():
        data[str(count)].append(td.get_text())
    else:
        data[str(count)] = [td.get_text()]        
    count += 1
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df = df.reindex(df.index.drop(0))
blank = blank.append(df)
# Out:
# /Users/mikephul/anaconda/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/mikephul/anaconda/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
def innerHTML(element):
    return element.decode_contents(formatter="html")
from bs4 import BeautifulSoup, NavigableString, Tag
count = 0

data = {"num_receive": [], "date_receive": []}
for td in table.findAll('td'):
    if count >= 5:
        mod = count%5
        if mod == 0:
            s = tf.get_text()
            print(s)
            
            
            
# #         if count %
#         print(td)

#         print(td.find('b'))

#         for br in td.findAll('br'):
#             next_s = br.nextSibling
#             if not (next_s and isinstance(next_s,NavigableString)):
#                 continue
#             next2_s = next_s.nextSibling
#             if next2_s and isinstance(next2_s,Tag) and next2_s.name == 'br':
#                 text = str(next_s).strip()
#                 if text:
#                     print("Found:", next_s)
#     count += 1
# Out:
# 5
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 31464<br/> รับวันที่ 10/10/2560		</td>
# None
# 6
# <td bgcolor="#ffffff" class="text" valign="top">6190010256</td>
# None
# 7
# <td bgcolor="#ffffff" class="text" valign="top"><b>นางสาวพัชนิดา เค้าแคน</b><br/>เจ้าพนักงานธุรการปฏิบัติงาน สำนักฝึกอบรม สถาบันพัฒนาข้าราชการฝ่ายอัยการ<br/>ส่วนราชการที่ไม่สังกัดกระทรวง/ทบวง<br/>สำนักงานอัยการสูงสุด<br/></td>
# <b>นางสาวพัชนิดา เค้าแคน</b>
# Found: เจ้าพนักงานธุรการปฏิบัติงาน สำนักฝึกอบรม สถาบันพัฒนาข้าราชการฝ่ายอัยการ
# Found: ส่วนราชการที่ไม่สังกัดกระทรวง/ทบวง
# Found: สำนักงานอัยการสูงสุด
# 8
# <td bgcolor="#ffffff" class="text" valign="top">กรณียักยอกเงินทดรองราชการโครงการอบรมหลักสูตรต่างๆ ของสถาบันพัฒนาข้าราชการฝ่ายอัยการไปใช้ส่วนตัว รวมเป็นเงินทั้งสิ้น 3,501,511.20 บาท</td>
# None
# 9
# <td bgcolor="#ffffff" class="text" valign="top">แจ้งคำสั่งมอบหมายพนักงานไต่สวน</td>
# None
# 10
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 30262<br/> รับวันที่ 26/09/2560		</td>
# None
# 11
# <td bgcolor="#ffffff" class="text" valign="top">6190010042</td>
# None
# 12
# <td bgcolor="#ffffff" class="text" valign="top"><b>นายวสวัตติ์ หรือนายสงกรานต์ กิตติธีระสิทธิ์ หรือสาทาวงศ์</b><br/>เมื่อครั้งดำรงตำแหน่งนักวิชาการศาสนาชำนาญการพิเศษ<br/>ส่วนราชการมีฐานะเป็นกรมไม่สังกัดสำนักนายกรัฐมนตรีหรือกระทรวง<br/>สำนักงานพระพุทธศาสนาแห่งชาติ<br/><b>กับพวก รวม 4 คน</b></td>
# <td bgcolor="#ffffff" class="text" valign="top"><b>นายเกริกฤทธิ์  อามาตร</b><br/>นายก อบต<br/>หน่วยงานองค์กรปกครองส่วนท้องถิ่น<br/>องค์การบริหารส่วนตำบล (อบต.)<br/><b>กับพวก รวม 29 คน</b></td>
# <b>นายเกริกฤทธิ์  อามาตร</b>
# Found: นายก อบต
# Found: หน่วยงานองค์กรปกครองส่วนท้องถิ่น
# Found: องค์การบริหารส่วนตำบล (อบต.)
# 33
# <td bgcolor="#ffffff" class="text" valign="top">ทุจริตการสอบแข่งขันมหาสารคาม ปี 2557</td>
# None
# 34
# <td bgcolor="#ffffff" class="text" valign="top">จัดทำคำสั่งแต่งตั้งคณะอนุกรรมการไต่สวน</td>
# None
# 35
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 23364<br/> รับวันที่ 24/09/2558		</td>
# None
# 36
# <td bgcolor="#ffffff" class="text" valign="top">6160070636</td>
# None
# 37
# <td bgcolor="#ffffff" class="text" valign="top"><b>นายบุญทัน สินธุเสน</b><br/>นายกอบต.เขื่อน<br/>หน่วยงานองค์กรปกครองส่วนท้องถิ่น<br/>องค์การบริหารส่วนตำบล (อบต.)<br/></td>
# <b>นายบุญทัน สินธุเสน</b>
# Found: นายกอบต.เขื่อน
# Found: หน่วยงานองค์กรปกครองส่วนท้องถิ่น
# Found: องค์การบริหารส่วนตำบล (อบต.)
# 38
# <td bgcolor="#ffffff" class="text" valign="top">ทุจริตการสอบแข่งขัน จังหวัดมหาสารคาม ปีพ.ศ. 2557</td>
# None
# 39
# <td bgcolor="#ffffff" class="text" valign="top">-</td>
# None
# 40
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ -<br/> รับวันที่ 31/10/2560		</td>
# None
# 41
# <td bgcolor="#ffffff" class="text" valign="top">6140440462</td>
# None
# 42
# <td bgcolor="#ffffff" class="text" valign="top"><b>(ไม่ระบุชื่อ-สกุลและตำแหน่ง) </b><br/>เจ้าหน้าที่เทศบาลตำบลหนองสอ<br/></td>
# <b>(ไม่ระบุชื่อ-สกุลและตำแหน่ง) </b>
# Found: เจ้าหน้าที่เทศบาลตำบลหนองสอ
# 43
# <td bgcolor="#ffffff" class="text" valign="top">ปฏิเสธไม่ขายแบบสอบราคาโครงการจ้างเหมาก่อสร้างถนนคอนกรีตเสริมเหล็ก ถนนสุขาภิบาล 2 เอื้ออำนวยแก่ผู้เข้าทำการเสนอราคาบางราย (เรื่องกล่าวหาเลขดำที่ 48980445 เลขแดงที่ 62789950)
# ออกเลขใหม่ตามมติคณะกรรมการ ป.ป.ช. ครั้งที่ 907-78/2560 วาระ 4.10 ลงวันที่ 10 ตุลาคม 2560 เสนอทบทวนมติคณะกรรมการ ป.ป.ช.
# ปกปิดการสอบราคาจ้างเหมาก่อสร้างถนน คสล. ถนนสุขาภิบาล 2 ระหว่าง หมู่ 4 - ปากคอสะพาน หมู่ 4 ตำบลลำปาว  ราคากลาง 450,000 บาท ตามประกาศ ลว. 1 ต.ค. 47
# เอกสารสอบราคาเลขที่ 14/2547  โดยปฏิเสธไม่ยินยอมขายแบบให้แก่ผู้กล่าวหา อ้างว่าไม่มีการสอบราคาแต่อย่างใด เป็นเหตุให้ผู้กล่าวหาเสียสิทธิ์ ในการเสนอราคาโครงการดังกล่าว และปรากฎว่า
#  ห้างหุ้นส่วนจำกัด หงษ์สายพินคอนสตรั๊คชั่น เป็นผู้เสนอราคาต่ำสุด และได้เป็นผู้รับจ้าง ตามสัญญาจ้างเลขที่ 2/2548 ลว. 22 ต.ค.47 ในวงเงิน 445,000 บาท  เหตุเกิดระหว่างวันที่ 1 - 8 ต.ค. 47</td>
# None
# 44
# <td bgcolor="#ffffff" class="text" valign="top">-</td>
# None
#
# 63
# <td bgcolor="#ffffff" class="text" valign="top">เป็นผู้สนับสนุนเจ้าพนักงานปฏิบัติหรือละเว้นการปฏัติหน้าที่โดยมิชอบ เพื่อให้เกิดความเสียหายแก่ผู้หนึ่งผู้ใดหรือปฏิบัติหรือละเว้นการปฏิบัติหน้าที่โดยทุจริต และร่วมกันบุกรุกที่สาธารณะ
# กรณีอนุมัติให้ นายเดชาวัต ศรีสารคาม เช่าที่ดินสาธารณะประโยชน์โคกหนองไผ่ เมื่อปี 2546 และเมื่อปี 2548 ได้ต่อสัญญาดังกล่าวเพิ่มอีก 15 ปี ต่อมาเมื่อปี 2552 เทศบาลตำบลขามเรียง (ขณะนั้น)
# ตรวจสอบพบว่าเทศบาลตำบลขามเรียง ไม่มีอำนาจตามกฎหมายที่จะให้ผู้อื่นเช่าที่สาธารณะสมบัติของแผ่นดิน เนื่องจากที่ดินดังกล่าวมหาวิทยาลัยมหาสารคาม ได้รับอนุมัติจากกระทรวงมหาดไทย ให้ใช้ที่ดินเป็นที่ตั้งของมหาวิทยาลัยเท่านั้น</td>
# None
# 64
# <td bgcolor="#ffffff" class="text" valign="top">-</td>
# None
# 65
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 000550/2559<br/> รับวันที่ 09/11/2559		</td>
# None
# 66
# <td bgcolor="#ffffff" class="text" valign="top">6090590567</td>
# None
# 67
# <td bgcolor="#ffffff" class="text" valign="top"><b>นางศิรวี วาเล๊าะ</b><br/>ท่องเที่ยวและกีฬาจังหวัดปัตตานี<br/>กระทรวงการท่องเที่ยวและกีฬา<br/><b>กับพวก รวม 2 คน</b></td>
# <b>นางศิรวี วาเล๊าะ</b>
# Found: ท่องเที่ยวและกีฬาจังหวัดปัตตานี
# Found: กระทรวงการท่องเที่ยวและกีฬา
# 68
# <td bgcolor="#ffffff" class="text" valign="top">ปลอมแปลงลายมือชื่อ นางพรนิดา ทองชุม , นายปัญญา เทพเฉลิม และ นางสุรีย์ โทบุรี ในใบตรวจรับการจัดซื้อ/จัดจ้าง ลงวันที่ 25 กันยายน 2556
# ซึ่งเป็นค่าจ้างผลิตสื่อประชาสัมพันธ์การท่องเที่ยวจังหวัดปัตตานี เป็นจำนวนเงิน 864,000 บาท</td>
# None
# 69
# <td bgcolor="#ffffff" class="text" valign="top">-</td>
# None
# 70
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 14756<br/> รับวันที่ 18/05/2560		</td>
# None
# 71
# <td bgcolor="#ffffff" class="text" valign="top">6090543002</td>
# None
# 72
# <td bgcolor="#ffffff" class="text" valign="top"><b>นายเสถียร ศรีชัย</b><br/></td>
# <b>นายเสถียร ศรีชัย</b>
# 73
# <td bgcolor="#ffffff" class="text" valign="top">เรียก รับ หรือยอมจะรับทรัพย์สินหรือประโยชน์อื่นใดสำหรับตนเอง หรือผู้อื่น โดยมิชอบเพื่อกระทำการในตำแหน่งไม่ว่าการนั้นจะชอบด้วยหน้าที่และเป็นเจ้าพนักงานปฏิบัติหน้าที่โดยมิชอบหรือโดยทุจริต พร้อมของกลางส่งพนักงานสอบสวนดำเนินคดีตามกฎหมาย</td>
# None
# 74
# <td bgcolor="#ffffff" class="text" valign="top">-</td>
# None
# 75
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 0110<br/> รับวันที่ 03/03/2560		</td>
# None
# 76
# <td bgcolor="#ffffff" class="text" valign="top">6090521725</td>
# None
# 77
# <td bgcolor="#ffffff" class="text" valign="top"><b>นางสาวโรซียะห์ เบ็นดือราแม</b><br/>ผู้อำนวยการ<br/>กระทรวงศึกษาธิการ<br/></td>
# <b>นางสาวโรซียะห์ เบ็นดือราแม</b>
# Found: ผู้อำนวยการ
# Found: กระทรวงศึกษาธิการ
# 78
# <td bgcolor="#ffffff" class="text" valign="top">กระทำความผิดฐานทุจริตต่อหน้าที่หรือกระทำความผิดต่อตำแหน่งหน้าที่ราชการ กรณี ปลอมลายมือชื่อผู้กล่าวหาในเอกสารใบถอนเงินของธนาคารกรุงไทย จำกัด (มหาชน) สาขานราธิวาส และนำลายมือชื่อปลอมที่อ้างว่าเป้นลายมือชื่อของผู้กล่าวหาไปถอนเงินออกจากบัญชีเลขที่ต่างๆ จากธนาคารกรุงไทย จำกัด (มหาชน) สาขานราธิวาส ซึ่งบัญชีเงินฝากทั้งหมดเป็นของโรงเรียนบ้านโคกสุมุ</td>
# None
# 79
# <td bgcolor="#ffffff" class="text" valign="top">แจ้งคำสั่งแต่งตั้งคณะอนุกรรมการไต่สวน</td>
# None
# 80
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ กส000649/2559<br/> รับวันที่ 26/12/2559		</td>
# None
# 81
# <td bgcolor="#ffffff" class="text" valign="top">6090441189</td>
# None
# 82
# <td bgcolor="#ffffff" class="text" valign="top"><b>นายเวียงชัย ราชฤทธิ์</b><br/>ผู้อำนวยการโรงเรียนท่าคันโทวิทยาคาร ระหว่างปฏิบัติหน้าที่ผู้อำนวยการโรงเรียนภูฮังพัฒนวิทย์<br/>กระทรวงศึกษาธิการ<br/></td>
# <b>นายเวียงชัย ราชฤทธิ์</b>
# Found: ผู้อำนวยการโรงเรียนท่าคันโทวิทยาคาร ระหว่างปฏิบัติหน้าที่ผู้อำนวยการโรงเรียนภูฮังพัฒนวิทย์
# Found: กระทรวงศึกษาธิการ
# 83
# <td bgcolor="#ffffff" class="text" valign="top">ระหว่างปฏิบัติหน้าที่ผู้อำนวยการโรงเรียนภูฮังพัฒนวิทย์ หมู่ที่ 3 ต.ดงมูล อ.หนองกุงศรี จ.กาฬสินธุ์ เมื่อปี 2557-2559 ว่าส่อไปในทางทุจริตหลายประการ เช่น รายงานข้อมูลนักเรียนสูงกว่าความเป็นจริงเพื่อหวังผลประโยชน์จากเงินที่เพิ่มขึ้น
# จัดหาชุดนักเรียนคุณภาพต่ำแจกให้นักเรียนแทนการจ่ายเงินสดให้กับผู้ปกครองและเบิกถอนเงินจากบัญชีเงินฝากของโรงเรียนโดยไม่ปฏิบัติตามระเบียบ</td>
# None
# 84
# <td bgcolor="#ffffff" class="text" valign="top">-</td>
# None
# 85
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ -<br/> รับวันที่ 		</td>
# None
# 86
# <td bgcolor="#ffffff" class="text" valign="top">6090074285</td>
# None
# 87
# <td bgcolor="#ffffff" class="text" valign="top"><b>นายดิเรก  ศรีเพียงจันทร์</b><br/>เจ้าหน้าที่วิเคราะห์นโยบายและแผน<br/>หน่วยงานองค์กรปกครองส่วนท้องถิ่น<br/></td>
# <b>นายดิเรก  ศรีเพียงจันทร์</b>
# Found: เจ้าหน้าที่วิเคราะห์นโยบายและแผน
# Found: หน่วยงานองค์กรปกครองส่วนท้องถิ่น
# 88
# <td bgcolor="#ffffff" class="text" valign="top">เรียกรับเงินจากน.ส.กานดา ลิลาสิทธิ ผู้สมัครสอบแข่งขันเพื่อบรรจุเป็นพนักงานส่วนตำบลของจังหวัดสุพรรณบุรี เป็นเงินจำนวน 100,000 บาท โดยอ้างว่าสามารถช่วยเหลือในการสอบแข่งขันเพื่อบรรจุเป็นพนักงานส่วนตำบลได้ </td>
# None
# 89
# <td bgcolor="#ffffff" class="text" valign="top">-</td>
# None
# 90
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 7578<br/> รับวันที่ 09/05/2546		</td>
# None
# 91
# <td bgcolor="#ffffff" class="text" valign="top">6090074017</td>
# None
# 92
# <td bgcolor="#ffffff" class="text" valign="top"><b>นายพุฒิเทวัญ วรรณเลิศ</b><br/>ปลัดองค์การบริหารส่วนตำบลขยาย<br/>กระทรวงมหาดไทย<br/>กรมส่งเสริมการปกครองท้องถิ่น<br/><b>กับพวก รวม 2 คน</b></td>
# <b>นายพุฒิเทวัญ วรรณเลิศ</b>
# Found: ปลัดองค์การบริหารส่วนตำบลขยาย
# Found: กระทรวงมหาดไทย
# Found: กรมส่งเสริมการปกครองท้องถิ่น
# 93
# <td bgcolor="#ffffff" class="text" valign="top">สมรู้กับบุคคลภายนอกสองคนซึ่งแอบอ้างว่าเป็นเจ้าหน้าที่สตง. นำเอกสารต่าง ๆ 13 รายการ ของ อบต.ขยาย โดยมิชอบ และเบียดบังเงิน ไปรวมทั้งหมด 1,160,531.04 บาท</td>
# None
# 94
# <td bgcolor="#ffffff" class="text" valign="top">เสนอคำสั่งมอบหมายองค์คณะพนักงานไต่สวน</td>
# None
# 95
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 06416<br/> รับวันที่ 18/04/2546		</td>
# None
# 96
# <td bgcolor="#ffffff" class="text" valign="top">6090074015</td>
# None
# 97
# <td bgcolor="#ffffff" class="text" valign="top"><b>นายพุฒเทวัญ วรรณเลิศ</b><br/>ปลัดองค์การบริหารส่วนตำบลขยาย <br/>หน่วยงานองค์กรปกครองส่วนท้องถิ่น<br/>เทศบาลตำบล<br/><b>กับพวก รวม 2 คน</b></td>
# <b>นายพุฒเทวัญ วรรณเลิศ</b>
# Found: ปลัดองค์การบริหารส่วนตำบลขยาย
# Found: หน่วยงานองค์กรปกครองส่วนท้องถิ่น
# Found: เทศบาลตำบล
# 98
# <td bgcolor="#ffffff" class="text" valign="top">ร่วมกันเบียดบังเงินของ อบต.ขยาย จำนวน 1,160,531.04 บาท ไปเป็นของตนเอง</td>
# None
# 99
# <td bgcolor="#ffffff" class="text" valign="top">เสนอคำสั่งมอบหมายองค์คณะพนักงานไต่สวน</td>
# None
# 100
# <td bgcolor="#ffffff" class="text" valign="top">เลขรับที่ 19171<br/> รับวันที่ 23/06/2560		</td>
# None
# 101
# <td bgcolor="#ffffff" class="text" valign="top">6090013650</td>
# None
# 102
# <td bgcolor="#ffffff" class="text" valign="top"><b>พันตำรวจเอกพิรพล อัจกลับ</b><br/>เมื่อครั้งดำรงตำแหน่งผู้กำกับการสืบสวน กองบังคับการตำรวจนครบาล 7<br/>ส่วนราชการมีฐานะเป็นกรมไม่สังกัดสำนักนายกรัฐมนตรีหรือกระทรวง<br/>สำนักงานตำรวจแห่งชาติ<br/><b>กับพวก รวม 2 คน</b></td>
# <b>พันตำรวจเอกพิรพล อัจกลับ</b>
# Found: เมื่อครั้งดำรงตำแหน่งผู้กำกับการสืบสวน กองบังคับการตำรวจนครบาล 7
# Found: ส่วนราชการมีฐานะเป็นกรมไม่สังกัดสำนักนายกรัฐมนตรีหรือกระทรวง
# Found: สำนักงานตำรวจแห่งชาติ
# 103
# <td bgcolor="#ffffff" class="text" valign="top">กรณีเบียดบังเงินล่อซื้อยาเสพติดจากกองบังคับการตำรวจนครบาล 7 เป็นจำนวนเงิน 1,000,000 บาท เป็นเหตุให้เกิดความเสียหายแก่ทางราชการ</td>
# None
# 104
# <td bgcolor="#ffffff" class="text" valign="top">-</td>
# None

# %%
blank.to_csv('nacc-0-19.csv')

# %%
df
# Out:
# 0                                          เลขรับที่    เลขดำที่  \
# 0                                          เลขรับที่    เลขดำที่
# 1           เลขรับที่ 31464 รับวันที่ 10/10/2560\t\t  6190010256
# 2           เลขรับที่ 30262 รับวันที่ 26/09/2560\t\t  6190010042
# 3           เลขรับที่ 23364 รับวันที่ 24/09/2558\t\t  6160071165
# 4           เลขรับที่ 23364 รับวันที่ 24/09/2558\t\t  6160070639
# 5           เลขรับที่ 23364 รับวันที่ 24/09/2558\t\t  6160070638
# 6           เลขรับที่ 23364 รับวันที่ 24/09/2558\t\t  6160070637
# 7           เลขรับที่ 23364 รับวันที่ 24/09/2558\t\t  6160070636
# 8               เลขรับที่ - รับวันที่ 31/10/2560\t\t  6140440462
# 9               เลขรับที่ - รับวันที่ 07/11/2560\t\t  6140080774
# 10              เลขรับที่ - รับวันที่ 25/10/2560\t\t  6140070375
# 11                       เลขรับที่ -- รับวันที่ \t\t  6090942561
# 12         เลขรับที่ มค0653 รับวันที่ 13/09/2559\t\t  6090940039
# 13    เลขรับที่ 000550/2559 รับวันที่ 09/11/2559\t\t  6090590567
# 14          เลขรับที่ 14756 รับวันที่ 18/05/2560\t\t  6090543002
# 15           เลขรับที่ 0110 รับวันที่ 03/03/2560\t\t  6090521725
# 16  เลขรับที่ กส000649/2559 รับวันที่ 26/12/2559\t\t  6090441189
# 17                        เลขรับที่ - รับวันที่ \t\t  6090074285
# 18           เลขรับที่ 7578 รับวันที่ 09/05/2546\t\t  6090074017
# 19          เลขรับที่ 06416 รับวันที่ 18/04/2546\t\t  6090074015
# 20          เลขรับที่ 19171 รับวันที่ 23/06/2560\t\t  6090013650
#
# 0                                       ผู้ถูกกล่าวหา  \
# 0                                       ผู้ถูกกล่าวหา
# 1   นางสาวพัชนิดา เค้าแคนเจ้าพนักงานธุรการปฏิบัติง...
# 2   นายวสวัตติ์ หรือนายสงกรานต์ กิตติธีระสิทธิ์ หร...
# 3   นายสวาท ปาธิสัตย์นายกองค์การบริหารส่วนตำบลดงดว...
# 4   นายยุทธภูมิ กุรัตน์นายก อบตหน่วยงานองค์กรปกครอ...
# 5   นายสุภาพ ผาบพุทธานายก อบตหน่วยงานองค์กรปกครองส...
# 6   นายเกริกฤทธิ์  อามาตรนายก อบตหน่วยงานองค์กรปกค...
# 7   นายบุญทัน สินธุเสนนายกอบต.เขื่อนหน่วยงานองค์กร...
# 8   (ไม่ระบุชื่อ-สกุลและตำแหน่ง) เจ้าหน้าที่เทศบาล...
# 9   นายสุนทร วิไลลักษณ์เมื่อครั้งดำรงตำแหน่งผู้อำน...
# 10  นายไกรษร มธิศิริกุลนายกองค์การบริหารส่วนตำบลรา...
# 11  นายสมภาร   เคนหาญนายกองค์การบริหารส่วนตำบลกุดจ...
# 12  นายมงคล  วงษ์วอนายกองค์การบริหารส่วนตำบลขามเรี...
# 13  นางศิรวี วาเล๊าะท่องเที่ยวและกีฬาจังหวัดปัตตาน...
# 14                                   นายเสถียร ศรีชัย
# 15  นางสาวโรซียะห์ เบ็นดือราแมผู้อำนวยการกระทรวงศึ...
# 16  นายเวียงชัย ราชฤทธิ์ผู้อำนวยการโรงเรียนท่าคันโ...
# 17  นายดิเรก  ศรีเพียงจันทร์เจ้าหน้าที่วิเคราะห์นโ...
# 18  นายพุฒิเทวัญ วรรณเลิศปลัดองค์การบริหารส่วนตำบล...
# 19  นายพุฒเทวัญ วรรณเลิศปลัดองค์การบริหารส่วนตำบลข...
# 20  พันตำรวจเอกพิรพล อัจกลับเมื่อครั้งดำรงตำแหน่งผ...
#
# 0                                          ข้อกล่าวหา  \
# 0                                          ข้อกล่าวหา
# 1   กรณียักยอกเงินทดรองราชการโครงการอบรมหลักสูตรต่...
# 2   กรณีทุจริตการเบิกเงินงบประมาณอุดหนุนการบูรณปฏิ...
# 3   การสอบแข่งขันบุคคลเพื่อบรรจุเป็นพนักงานส่วนตำบ...
# 4   ร่วมกันทุจริตในการสอบแข่งขันบุคคลเพื่อบรรจุเป็...
# 5
# 6                ทุจริตการสอบแข่งขันมหาสารคาม ปี 2557
# 7    ทุจริตการสอบแข่งขัน จังหวัดมหาสารคาม ปีพ.ศ. 2557
# 8   ปฏิเสธไม่ขายแบบสอบราคาโครงการจ้างเหมาก่อสร้างถ...
# 9   เรียกเก็บเงินค่าเรียนพิเศษในวันเสาร์ โดยไม่ออก...
# 10  กรณีกล่าวหานายไกรษร มธิศิริกุล นายกองค์การบริห...
# 11  เรียกรับเงินเพื่อช่วยเหลือให้ได้รับการคัดเลือก...
# 12  เป็นผู้สนับสนุนเจ้าพนักงานปฏิบัติหรือละเว้นการ...
# 13  ปลอมแปลงลายมือชื่อ นางพรนิดา ทองชุม , นายปัญญา...
# 14  เรียก รับ หรือยอมจะรับทรัพย์สินหรือประโยชน์อื่...
# 15  กระทำความผิดฐานทุจริตต่อหน้าที่หรือกระทำความผิ...
# 16  ระหว่างปฏิบัติหน้าที่ผู้อำนวยการโรงเรียนภูฮังพ...
# 17  เรียกรับเงินจากน.ส.กานดา ลิลาสิทธิ ผู้สมัครสอบ...
# 18  สมรู้กับบุคคลภายนอกสองคนซึ่งแอบอ้างว่าเป็นเจ้า...
# 19  ร่วมกันเบียดบังเงินของ อบต.ขยาย จำนวน 1,160,53...
# 20  กรณีเบียดบังเงินล่อซื้อยาเสพติดจากกองบังคับการ...
#
# 0                              สถานะล่าสุด
# 0                              สถานะล่าสุด
# 1           แจ้งคำสั่งมอบหมายพนักงานไต่สวน
# 2                                        -
# 3                                        -
# 4    แจ้งคำสั่งแต่งตั้งคณะอนุกรรมการไต่สวน
# 5                        สอบปากคำพยานบุคคล
# 6   จัดทำคำสั่งแต่งตั้งคณะอนุกรรมการไต่สวน
# 7                                        -
# 8                                        -
# 9                                        -
# 10                                       -
# 11                                       -
# 12                                       -
# 13                                       -
# 14                                       -
# 15   แจ้งคำสั่งแต่งตั้งคณะอนุกรรมการไต่สวน
# 16                                       -
# 17                                       -
# 18   เสนอคำสั่งมอบหมายองค์คณะพนักงานไต่สวน
# 19   เสนอคำสั่งมอบหมายองค์คณะพนักงานไต่สวน
# 20                                       -
